# %% [markdown]
# # level 1

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('input/data.csv', header=None)

# %%
df
# Out:
#              0         1         2         3         4
# 0    -0.187421  0.131230  0.143893 -0.185476 -0.126729
# 1     1.619760  1.165669  1.123722  1.618634 -2.007404
# 2     0.508120  0.605804  0.601210  0.513154  0.734771
# 3    -0.801372 -0.510272 -0.463632 -0.803233  0.091330
# 4    -0.558647 -0.211937 -0.181563 -0.559327 -1.008862
# ...        ...       ...       ...       ...       ...
# 1995  0.979292  0.865800  0.841783  0.983651  1.194655
# 1996  1.434147  1.076005  1.048022  1.431939 -1.067240
# 1997 -0.077276  0.217731  0.223425 -0.082174  0.704316
# 1998  1.181223  0.967514  0.932469  1.180012  1.456029
# 1999  0.967054  0.855408  0.837171  0.967439  0.864500
#
# [2000 rows x 5 columns]

# %%
data = np.array(df)

pca = PCA(n_components=2)
projected_data = pca.fit_transform(data)

#get variance of each component
explained_variance = pca.explained_variance_
std_devs = np.round(np.sqrt(explained_variance), 2)
print(std_devs)
# Out:
# [1.97 1.  ]

# %% [markdown]
# # level 2

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(projected_data[:, 0], projected_data[:, 1])
plt.show()
