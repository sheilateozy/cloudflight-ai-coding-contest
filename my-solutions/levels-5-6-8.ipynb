# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, Normalizer, RobustScaler, OneHotEncoder, TargetEncoder
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import optuna

# %%
#get data
train_clean = pd.read_csv('../prediction-task/train-clean.csv')
test_clean = pd.read_csv('../prediction-task/test-clean.csv')

# %%
#ensure cat cols are understood to be cat
for cat_col in ['MODE', 'POWER']:
    train_clean[cat_col] = train_clean[cat_col].astype('category')
    test_clean[cat_col] =  test_clean[cat_col].astype('category')

# %%
#get training features & target
X = train_clean.drop('OUTPUT', axis='columns')
y = train_clean['OUTPUT']

# %%
#split data into train and val sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
num_cols = ['AMPS', 'VOLTS', 'TEMP', 'DELTA', 'GAMMA']
cat_cols = ['POWER', 'MODE']

#custom func to calculate rmse
def get_rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

#preprocessing funcs
def get_num_transformer(scaler_type):
    if scaler_type == 'StandardScaler':
        num_transformer = Pipeline(steps=[('scaler', StandardScaler())])
    elif scaler_type == 'MinMaxScaler':
        num_transformer = Pipeline(steps=[('scaler', MinMaxScaler())])
    elif scaler_type == 'MaxAbsScaler':
        num_transformer = Pipeline(steps=[('scaler', MaxAbsScaler())])
    elif scaler_type == 'Normalizer':
        num_transformer = Pipeline(steps=[('scaler', Normalizer())])
    elif scaler_type == 'RobustScaler':
        num_transformer = Pipeline(steps=[('scaler', RobustScaler())])
    return num_transformer

def get_cat_transformer(encoder_type):
    if encoder_type == 'OneHotEncoder':
        cat_transformer = Pipeline(steps=[('encoder', OneHotEncoder())])
    elif encoder_type == 'TargetEncoder':
        cat_transformer = Pipeline(steps=[('encoder', TargetEncoder())])
    return cat_transformer

def get_preprocessor(scaler_type, encoder_type, num_cols, cat_cols):
    preprocessor = ColumnTransformer(
        transformers=[
            ('scale', get_num_transformer(scaler_type), num_cols),
            ('encode', get_cat_transformer(encoder_type), cat_cols)
        ])
    return preprocessor

#objective function for hyperparam tuning
def objective(trial):
    #tune preprocessing params
    scaler_type = trial.suggest_categorical('scaler_type', ['StandardScaler', 'MinMaxScaler', 'MaxAbsScaler', 'Normalizer', 'RobustScaler'])
    encoder_type = trial.suggest_categorical('encoder_type', ['OneHotEncoder', 'TargetEncoder'])
    preprocessor = get_preprocessor(scaler_type, encoder_type, num_cols, cat_cols)
        
    #tune model type
    regressor_type = trial.suggest_categorical('regressor_type', ['XGBRegressor', 'RandomForestRegressor'])
    
    if regressor_type == 'XGBRegressor':
        #tune modelling params
        regressor_params = {
            'max_depth': trial.suggest_int('max_depth', 1, 10),  #shallow trees bc gradient boosting
            'n_estimators': trial.suggest_int('n_estimators', 20, 1000),
            'subsample': trial.suggest_float('subsample', 0.5, 1),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1),
            'gamma': trial.suggest_float('gamma', 0, 0.5),
            'reg_alpha': trial.suggest_categorical('reg_alpha', [0, 0.001, 0.005, 0.01, 0.05]),
            'reg_lambda': trial.suggest_categorical('reg_lambda', [0, 0.001, 0.005, 0.01, 0.05]),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 50),
            'learning_rate': 0.1
        }
        regressor = XGBRegressor(**regressor_params)

    elif regressor_type == 'RandomForestRegressor':
        #tune modelling params
        regressor_params = {
            'n_estimators': trial.suggest_int('n_estimators', 50, 3000),
            'max_depth': trial.suggest_int('max_depth', 5, 50),  #deep trees bc rf
            'min_samples_split': trial.suggest_int('min_samples_split', 2, 15),
            'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 14),
            'max_features': trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
        }
        regressor = RandomForestRegressor(**regressor_params)

    #full modelling pipeline
    pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                ('regressor', regressor)])
    
    #create rmse scorer from custom rmse func
    rmse_scorer = make_scorer(get_rmse)

    #get cv rmse
    all_rmse = cross_val_score(pipeline, X_train, y_train, scoring=rmse_scorer, n_jobs=-1, cv=5)
    mean_rmse = all_rmse.mean()
    return mean_rmse

#tune hyperparams using optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-12-15 16:49:01,698] A new study created in memory with name: no-name-e3499e69-d57f-4cf5-896d-31a7be7b508d
# [I 2023-12-15 16:49:07,312] Trial 0 finished with value: 1.0760568833836626 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2858, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 0 with value: 1.0760568833836626.
# [I 2023-12-15 16:49:07,863] Trial 1 finished with value: 1.1522878219282713 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 7, 'n_estimators': 570, 'subsample': 0.5495344213158437, 'colsample_bytree': 0.579395998891445, 'gamma': 0.19398055805783082, 'reg_alpha': 0.01, 'reg_lambda': 0, 'min_child_weight': 49}. Best is trial 0 with value: 1.0760568833836626.
# [I 2023-12-15 16:49:08,790] Trial 2 finished with value: 0.9694698747219596 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 278, 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:08,894] Trial 3 finished with value: 1.1816015442974996 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 5, 'n_estimators': 379, 'subsample': 0.6276630617178796, 'colsample_bytree': 0.47311642062717546, 'gamma': 0.3608293290958803, 'reg_alpha': 0.05, 'reg_lambda': 0.005, 'min_child_weight': 18}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:11,446] Trial 4 finished with value: 1.027845848878354 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1728, 'max_depth': 41, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:11,511] Trial 5 finished with value: 1.183031233110151 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 9, 'n_estimators': 229, 'subsample': 0.7137434676883128, 'colsample_bytree': 0.3705482726584171, 'gamma': 0.458620399985807, 'reg_alpha': 0.05, 'reg_lambda': 0.001, 'min_child_weight': 39}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:12,170] Trial 6 finished with value: 1.3083596453736892 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 806, 'max_depth': 38, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_features': 'log2'}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:12,269] Trial 7 finished with value: 1.0997397293430096 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 6, 'n_estimators': 452, 'subsample': 0.6488672770089403, 'colsample_bytree': 0.9417895818750366, 'gamma': 0.19186218914419617, 'reg_alpha': 0, 'reg_lambda': 0.005, 'min_child_weight': 50}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:14,938] Trial 8 finished with value: 1.582232898279826 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2586, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 11, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:15,174] Trial 9 finished with value: 1.1437249538560483 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 8, 'n_estimators': 968, 'subsample': 0.6635796144252355, 'colsample_bytree': 0.5722914969800732, 'gamma': 0.30273615620129096, 'reg_alpha': 0, 'reg_lambda': 0, 'min_child_weight': 30}. Best is trial 2 with value: 0.9694698747219596.
# [I 2023-12-15 16:49:18,155] Trial 10 finished with value: 0.9047042508312257 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1616, 'max_depth': 47, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:20,809] Trial 11 finished with value: 0.9072531324724199 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1476, 'max_depth': 50, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:24,676] Trial 12 finished with value: 0.9132766488430454 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1667, 'max_depth': 50, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:28,968] Trial 13 finished with value: 0.9141423096082987 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2182, 'max_depth': 50, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:30,354] Trial 14 finished with value: 1.4511268266545332 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1268, 'max_depth': 44, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:32,682] Trial 15 finished with value: 1.3834001128189508 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2018, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:35,412] Trial 16 finished with value: 0.9347339787850799 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1283, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:40,056] Trial 17 finished with value: 0.9299490934029804 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2121, 'max_depth': 46, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:42,919] Trial 18 finished with value: 0.914145253023616 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1352, 'max_depth': 31, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:45,368] Trial 19 finished with value: 1.4977993394355518 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 923, 'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:47,797] Trial 20 finished with value: 1.295620247666183 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1838, 'max_depth': 45, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:51,346] Trial 21 finished with value: 0.9100733933130541 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1630, 'max_depth': 49, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:55,181] Trial 22 finished with value: 0.9141616668914093 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1531, 'max_depth': 50, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:49:59,909] Trial 23 finished with value: 0.9142774146478377 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2312, 'max_depth': 37, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:50:02,256] Trial 24 finished with value: 0.9431762308422833 and parameters: {'scaler_type': 'Normalizer', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1193, 'max_depth': 42, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 10 with value: 0.9047042508312257.
# [I 2023-12-15 16:50:06,401] Trial 25 finished with value: 0.845935576066435 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1943, 'max_depth': 47, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:06,547] Trial 26 finished with value: 2.4167665232258 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 1, 'n_estimators': 806, 'subsample': 0.9827410440423612, 'colsample_bytree': 0.8323520848565666, 'gamma': 0.009686629677444103, 'reg_alpha': 0.005, 'reg_lambda': 0.05, 'min_child_weight': 1}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:10,912] Trial 27 finished with value: 0.9208318661901839 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2437, 'max_depth': 46, 'min_samples_split': 5, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:13,126] Trial 28 finished with value: 1.2945444337115217 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2010, 'max_depth': 41, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:16,482] Trial 29 finished with value: 1.4571200113874287 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2979, 'max_depth': 32, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:19,955] Trial 30 finished with value: 0.9091456641655699 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1863, 'max_depth': 35, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:23,091] Trial 31 finished with value: 0.8893226570906292 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1842, 'max_depth': 47, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:25,660] Trial 32 finished with value: 0.8711551215465521 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1450, 'max_depth': 46, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:31,391] Trial 33 finished with value: 0.8680350643868401 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2706, 'max_depth': 47, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:31,483] Trial 34 finished with value: 1.4836581004439064 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 3, 'n_estimators': 51, 'subsample': 0.8536179201625487, 'colsample_bytree': 0.30673521212725346, 'gamma': 0.4978725677185803, 'reg_alpha': 0.001, 'reg_lambda': 0.01, 'min_child_weight': 2}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:35,944] Trial 35 finished with value: 0.8980092626640968 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2686, 'max_depth': 42, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:40,487] Trial 36 finished with value: 0.9369341870396528 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2690, 'max_depth': 39, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:40,752] Trial 37 finished with value: 1.1797648430385066 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 9, 'n_estimators': 647, 'subsample': 0.5007598009656543, 'colsample_bytree': 0.6826225661218618, 'gamma': 0.002915509449800291, 'reg_alpha': 0.001, 'reg_lambda': 0.001, 'min_child_weight': 16}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:44,416] Trial 38 finished with value: 1.0054388338433269 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2362, 'max_depth': 43, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:47,956] Trial 39 finished with value: 0.8880506599239328 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1887, 'max_depth': 34, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:48,191] Trial 40 finished with value: 1.0569276697215946 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 9, 'n_estimators': 693, 'subsample': 0.8076008881092638, 'colsample_bytree': 0.990159349601732, 'gamma': 0.12369230540759585, 'reg_alpha': 0.005, 'reg_lambda': 0.01, 'min_child_weight': 31}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:51,294] Trial 41 finished with value: 0.9001923163574638 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1849, 'max_depth': 34, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:53,657] Trial 42 finished with value: 0.9171774608642549 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1451, 'max_depth': 40, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:50:57,073] Trial 43 finished with value: 0.8760296888965977 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1973, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:01,310] Trial 44 finished with value: 0.8727969523257262 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2238, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:05,651] Trial 45 finished with value: 0.8656065760713387 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2452, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:08,599] Trial 46 finished with value: 1.2685805540535335 and parameters: {'scaler_type': 'RobustScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2536, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:13,364] Trial 47 finished with value: 0.8639058789880483 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2764, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:13,544] Trial 48 finished with value: 1.1084005883512842 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 4, 'n_estimators': 906, 'subsample': 0.9760847603597058, 'colsample_bytree': 0.7624379365453322, 'gamma': 0.37400534177984524, 'reg_alpha': 0.01, 'reg_lambda': 0.05, 'min_child_weight': 14}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:15,907] Trial 49 finished with value: 1.3078396645809962 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2823, 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:20,891] Trial 50 finished with value: 0.886392684939296 and parameters: {'scaler_type': 'MinMaxScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2928, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:24,634] Trial 51 finished with value: 0.8668142606332054 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2201, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:29,491] Trial 52 finished with value: 0.8555501231631958 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2499, 'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:34,400] Trial 53 finished with value: 0.869558658072316 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2781, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:39,060] Trial 54 finished with value: 0.872622460064651 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2544, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:42,457] Trial 55 finished with value: 1.0866341665146757 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2426, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:47,267] Trial 56 finished with value: 0.8664914960590526 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2654, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:51,255] Trial 57 finished with value: 0.8671433362080357 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2163, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:53,871] Trial 58 finished with value: 1.25629135521199 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2534, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:56,137] Trial 59 finished with value: 1.3054417558411324 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2275, 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:51:59,144] Trial 60 finished with value: 1.007581813154957 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2110, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:02,997] Trial 61 finished with value: 0.8678167821858296 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2148, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:07,119] Trial 62 finished with value: 0.8694038574892835 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2449, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:12,100] Trial 63 finished with value: 0.8787269965992179 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2621, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:16,081] Trial 64 finished with value: 0.8615338199488477 and parameters: {'scaler_type': 'MaxAbsScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2349, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:20,282] Trial 65 finished with value: 0.853695278772653 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2374, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:25,087] Trial 66 finished with value: 0.8811242301320472 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2903, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:25,341] Trial 67 finished with value: 1.1587918346737636 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 7, 'n_estimators': 979, 'subsample': 0.7973538014400622, 'colsample_bytree': 0.8338389007802324, 'gamma': 0.2577551909642282, 'reg_alpha': 0.05, 'reg_lambda': 0.05, 'min_child_weight': 39}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:29,545] Trial 68 finished with value: 0.8543709742060512 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'TargetEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2368, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:33,882] Trial 69 finished with value: 0.8614395136082489 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2417, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:36,115] Trial 70 finished with value: 0.9932914347676887 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2364, 'max_depth': 28, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:40,374] Trial 71 finished with value: 0.8692216808696982 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2492, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:44,486] Trial 72 finished with value: 0.8883809395511031 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2331, 'max_depth': 25, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:48,945] Trial 73 finished with value: 0.9086930070677683 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2803, 'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:52,752] Trial 74 finished with value: 0.8630231098713441 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2061, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:54,382] Trial 75 finished with value: 1.0237641812526355 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1737, 'max_depth': 30, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:52:57,884] Trial 76 finished with value: 0.8593543992837287 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2067, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:02,067] Trial 77 finished with value: 0.860482857540943 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2277, 'max_depth': 31, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:05,241] Trial 78 finished with value: 0.8822825466786203 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1945, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:05,395] Trial 79 finished with value: 1.2454782584075725 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 6, 'n_estimators': 991, 'subsample': 0.875175524791526, 'colsample_bytree': 0.4520556036260719, 'gamma': 0.09082410358446025, 'reg_alpha': 0.01, 'reg_lambda': 0.01, 'min_child_weight': 10}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:08,986] Trial 80 finished with value: 0.9066136287003295 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2245, 'max_depth': 37, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:13,016] Trial 81 finished with value: 0.8613009508846583 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2083, 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:16,955] Trial 82 finished with value: 0.8663114749020473 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2076, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:20,842] Trial 83 finished with value: 0.8744723861236027 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 2371, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:24,070] Trial 84 finished with value: 0.8576402603400954 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1712, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:26,926] Trial 85 finished with value: 0.9579771346891738 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1725, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 25 with value: 0.845935576066435.
# [I 2023-12-15 16:53:30,860] Trial 86 finished with value: 0.838855521744873 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1946, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 86 with value: 0.838855521744873.
# [I 2023-12-15 16:53:35,335] Trial 87 finished with value: 0.8334564427044497 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1931, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:39,099] Trial 88 finished with value: 0.8389392711736502 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1586, 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:41,261] Trial 89 finished with value: 0.8905250878259743 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1772, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:44,827] Trial 90 finished with value: 0.8386020058516651 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1510, 'max_depth': 23, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:48,147] Trial 91 finished with value: 0.8398617222058844 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1625, 'max_depth': 23, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:51,398] Trial 92 finished with value: 0.8353629299034514 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1593, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:55,048] Trial 93 finished with value: 0.8414515419770761 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1539, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:53:58,484] Trial 94 finished with value: 0.8336674192130706 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1543, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:54:01,946] Trial 95 finished with value: 0.8346099427412639 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1568, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:54:02,155] Trial 96 finished with value: 1.1172379919184101 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'XGBRegressor', 'max_depth': 8, 'n_estimators': 988, 'subsample': 0.7219251117534191, 'colsample_bytree': 0.6164281581501946, 'gamma': 0.41194295609757875, 'reg_alpha': 0.005, 'reg_lambda': 0.001, 'min_child_weight': 24}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:54:04,336] Trial 97 finished with value: 0.892326198053164 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1557, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:54:07,131] Trial 98 finished with value: 0.837011847485177 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1369, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.
# [I 2023-12-15 16:54:09,908] Trial 99 finished with value: 0.836736530470594 and parameters: {'scaler_type': 'StandardScaler', 'encoder_type': 'OneHotEncoder', 'regressor_type': 'RandomForestRegressor', 'n_estimators': 1327, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 87 with value: 0.8334564427044497.

# %%
#get best hyperparams found
best_params = study.best_trial.params
best_params
# Out:
# {'scaler_type': 'StandardScaler',
#  'encoder_type': 'OneHotEncoder',
#  'regressor_type': 'RandomForestRegressor',
#  'n_estimators': 1931,
#  'max_depth': 26,
#  'min_samples_split': 3,
#  'min_samples_leaf': 1,
#  'max_features': None}

# %%
#get best modelling pipeline
best_preprocessor = get_preprocessor(best_params['scaler_type'], best_params['encoder_type'], num_cols, cat_cols)
del best_params['scaler_type']
del best_params['encoder_type']

if best_params['regressor_type'] == 'XGBRegressor':
    del best_params['regressor_type']
    best_params['learning_rate'] = 0.1
    best_regressor = XGBRegressor(**best_params) 
elif best_params['regressor_type'] == 'RandomForestRegressor':
    del best_params['regressor_type']
    best_regressor = RandomForestRegressor(**best_params)

best_pipeline = Pipeline(steps=[('preprocessor', best_preprocessor),
                                ('regressor', best_regressor)])

# %%
best_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scale',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['AMPS', 'VOLTS', 'TEMP',
#                                                    'DELTA', 'GAMMA']),
#                                                  ('encode',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder())]),
#                                                   ['POWER', 'MODE'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=26, max_features=None,
#                                        min_samples_split=3,
#                                        n_estimators=1931))])

# %%
#evaluate best model on val set
predictions = best_pipeline.predict(X_val)
val_rmse = get_rmse(y_val, predictions)
print(val_rmse)
# Out:
# 0.5048696741536496

# %%
#get predictions on test set

# %%
predictions = best_pipeline.predict(test_clean)

# %%
predictions = pd.DataFrame(predictions)
predictions.to_csv('../test_preds.csv', header=None, index=False)

# %%
predictions
# Out:
#              0
# 0     2.305053
# 1     2.164949
# 2     2.072999
# 3     1.987497
# 4     2.135739
# ...        ...
# 2495  2.518213
# 2496  2.428236
# 2497  1.967197
# 2498  2.092365
# 2499  1.995292
#
# [2500 rows x 1 columns]
